# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("data.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
null=data.isnull().sum()
print(null.to_string())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
print(data.isnull().sum()[data.isnull().sum()>0])
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
print(data.isnull().sum()[data.isnull().sum()>0].count())
# Out:
# 19

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
data.Alley.value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
data.MasVnrType.value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
data.BsmtQual.value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
data.BsmtCond.value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
data.BsmtExposure.value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
data.BsmtFinType1.value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
data.BsmtFinType2.value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
data.Electrical.value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
data.FireplaceQu.value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
data.GarageType.value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
data.GarageFinish.value_counts()
# Out:
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64

# %%
data.GarageQual.value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
data.GarageCond.value_counts()
# Out:
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
data.PoolQC.value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
data.Fence.value_counts()
# Out:
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64

# %%
data.MiscFeature.value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
#There are 19 columns with null values ,of which LotFrontage,MasVnrArea,GarageYrBlt are numerical.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(numeric_only=True),annot=True,fmt=".2f",cmap="coolwarm")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=data.drop("Id",axis=1)

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder,FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
non_null_cols=data.columns[data.isnull().sum()==0]
print(non_null_cols)
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
no_trans=['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
       'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
       'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
       'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
       'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
       'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']
numerical_cols=["LotFrontage","MasVnrArea","GarageYrBlt"]
categorical_cols=["Alley","MasVnrType","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2","Electrical","FireplaceQu","GarageType",
                  "GarageFinish","GarageQual","GarageCond","PoolQC","Fence","MiscFeature"]

# %%
def same(x):
    return(x)

# %%
passthrough=FunctionTransformer(same)

# %%
num_pipeline=Pipeline([("imputer",SimpleImputer(strategy='median'))])
cat_pipeline=Pipeline([("imputer",SimpleImputer(strategy='most_frequent'))])

# %%
impute=ColumnTransformer([("pass",passthrough,no_trans),('num',num_pipeline,numerical_cols),('cat',cat_pipeline,categorical_cols)])

# %%
data=impute.fit_transform(data)

# %%
data=pd.DataFrame(data,columns=no_trans+numerical_cols+categorical_cols)
data.isnull().sum()
# Out:
# MSSubClass     0
# MSZoning       0
# LotArea        0
# Street         0
# LotShape       0
#               ..
# GarageQual     0
# GarageCond     0
# PoolQC         0
# Fence          0
# MiscFeature    0
# Length: 80, dtype: int64

# %%
nulls=data.isnull().sum()
print(nulls.to_string())
# Out:
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageCars       0
# ...

# %%
data.shape
# Out:
# (1460, 80)

# %%
X=data.drop("SalePrice",axis=1)
y=data["SalePrice"]

# %%
X
# Out:
#      MSSubClass MSZoning LotArea Street LotShape LandContour Utilities  \
# 0            60       RL    8450   Pave      Reg         Lvl    AllPub
# 1            20       RL    9600   Pave      Reg         Lvl    AllPub
# 2            60       RL   11250   Pave      IR1         Lvl    AllPub
# 3            70       RL    9550   Pave      IR1         Lvl    AllPub
# 4            60       RL   14260   Pave      IR1         Lvl    AllPub
# ...         ...      ...     ...    ...      ...         ...       ...
# 1455         60       RL    7917   Pave      Reg         Lvl    AllPub
# 1456         20       RL   13175   Pave      Reg         Lvl    AllPub
# 1457         70       RL    9042   Pave      Reg         Lvl    AllPub
# 1458         20       RL    9717   Pave      Reg         Lvl    AllPub
# 1459         20       RL    9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# ...

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: object

# %%
for col in X.columns:
    X[col]=pd.to_numeric(X[col],errors="ignore")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18404\1718317381.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   X[col]=pd.to_numeric(X[col],errors="ignore")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  OverallQual    1460 non-null   int64
#  15  OverallCond    1460 non-null   int64
#  16  YearBuilt      1460 non-null   int64
# ...

# %%
year_features=["YearBuilt","YearRemodAdd","YrSold"]
num_features=X.select_dtypes(include=["int64","float64"]).columns.tolist()
cat_features=X.select_dtypes(include=['object','category']).columns.tolist()

# %%
cat_features
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition',
#  'Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
num_features=[col for col in num_features if col not in year_features]
num_features
# Out:
# ['MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'LotFrontage',
#  'MasVnrArea',
#  'GarageYrBlt']

# %%
preprocessor=ColumnTransformer([("num",StandardScaler(),num_features),("date",passthrough,year_features),("cat",OneHotEncoder(handle_unknown="ignore",sparse_output=False),cat_features)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['MSSubClass', 'LotArea', 'OverallQual',
#                                   'OverallCond', 'BsmtFinSF1', 'BsmtFinSF2',
#                                   'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#                                   '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#                                   'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#                                   'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#                                   'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#                                   'GarageArea', 'Wood...
#                                  ['MSZoning', 'Street', 'LotShape',
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
#                                   'Condition2', 'BldgType', 'HouseStyle',
# ...

# %%
from sklearn.linear_model import Lasso

# %%
X_transformed=preprocessor.fit_transform(X)
X_transformed
# Out:
# array([[ 0.07337496, -0.20714171,  0.65147924, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.87256276, -0.09188637, -0.07183611, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.07337496,  0.07347998,  0.65147924, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.30985939, -0.14781027,  0.65147924, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.87256276, -0.08016039, -0.79515147, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.87256276, -0.05811155, -0.79515147, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
X_transformed.shape
# Out:
# (1460, 287)

# %%
y.shape
# Out:
# (1460,)

# %%
feature_names=[]
for name,transformer,cols in preprocessor.transformers_:
    if transformer=='passthrough':
        if isinstance(cols,list):
            feature_names.extend(cols)
        else:
            feature_names.append(cols)
    elif isinstance(transformer,Pipeline):
        last_step=transformer.steps[-1][1]
        if hasattr(last_step,'get_feature_name_out'):
            transformed=last_step.get_feature_names_out(cols)
            feature_names.extend([f"{name}__{f}" for f in transformed])
        else:
            feature_names.extend([f"{name}__{col}"for col in cols])
    elif hasattr(transformer,'get_feature_names_out'):
        transformed=transformer.get_feature_names_out(cols)
        feature_names.extend([f"{name}__{f}" for f in transformed])
    else:
        feature_names.extend([f"{name}__{col}" for col in cols])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_transformed,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv=LassoCV(cv=5,random_state=3)
lasso_cv.fit(X_train,y_train)
print("Best alpha:",lasso_cv.alpha_)
# Out:
# Best alpha: 1272.4988444962123

# %%
lasso=Lasso(alpha=1272,random_state=3)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=1272, random_state=3)

# %%
lasso.coef_.shape
# Out:
# (287,)

# %%
selected_mask=lasso.coef_!=0
selected_features=np.array(feature_names)[selected_mask]
selected_features
# Out:
# array(['num__MSSubClass', 'num__LotArea', 'num__OverallQual',
#        'num__OverallCond', 'num__BsmtFinSF1', 'num__TotalBsmtSF',
#        'num__GrLivArea', 'num__BsmtFullBath', 'num__BedroomAbvGr',
#        'num__KitchenAbvGr', 'num__Fireplaces', 'num__GarageCars',
#        'num__GarageArea', 'num__WoodDeckSF', 'num__ScreenPorch',
#        'num__PoolArea', 'num__MoSold', 'num__LotFrontage',
#        'num__MasVnrArea', 'date__YearBuilt', 'date__YearRemodAdd',
#        'cat__Condition1_Norm', 'cat__ExterQual_TA',
#        'cat__Foundation_CBlock', 'cat__KitchenQual_Ex',
#        'cat__KitchenQual_TA', 'cat__BsmtQual_Ex', 'cat__BsmtExposure_Gd',
#        'cat__BsmtExposure_No'], dtype='<U26')

# %%
selected_mask.sum()
# Out:
# 29

# %%
X_train_selected=X_train[:,selected_mask]
X_test_selected=X_test[:,selected_mask]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train_selected,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred_lr=lr.predict(X_train_selected)
y_train_pred_lr[:10]
# Out:
# array([203493.94343172, 161022.15048564, 197992.63925633, 117650.96150852,
#        136853.77891387, 108849.1338505 , 125644.03176152, 288929.19717029,
#        322665.19509653, 264217.18769089])

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_lr=lr.predict(X_test_selected)
y_pred_lr[:10]
# Out:
# array([ 90560.14673427, 127943.86042379, 196598.9536661 , 182665.7162808 ,
#        306915.21924669,  57047.51196554, 170871.14647344, 113566.67240659,
#        143609.68601036, 102093.40061072])

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_lr=r2_score(y_pred_lr,y_test)
mae_lr=mean_absolute_error(y_pred_lr,y_test)
mse_lr=mean_squared_error(y_pred_lr,y_test)
relative_error_lr=mae_lr/(np.mean(y_test))*100
print("r2score lr:",r2_lr)
print("mean absolute error lr:",mae_lr)
print("mean squared error lr:",mse_lr)
print("relative error lr:",relative_error_lr)
# Out:
# r2score lr: 0.6532366150437715
# mean absolute error lr: 19297.632433247025
# mean squared error lr: 2290055176.32147
# relative error lr: 10.826230309117864

# %%
from sklearn.neighbors import KNeighborsRegressor
train_score=[]
test_score=[]
k_range=(1,20)
for k in k_range:
    knn=KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_selected,y_train)
    y_train_pred_knn=knn.predict(X_train_selected)
    y_pred_knn=knn.predict(X_test_selected)
    train_score.append(r2_score(y_train_pred_knn,y_train))
    test_score.append(r2_score(y_pred_knn,y_test))
plt.figure(figsize=(15,10))
plt.plot(k_range,train_score,label='train score',marker="+")
plt.plot(k_range,test_score,label='test score',marker='o')
plt.xlabel("n_neighbors")
plt.ylabel("Score")
plt.title("K vs Score")
plt.grid(True)
plt.legend()
plt.show()

# %%
knn=KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train_selected,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_train_pred_knn=knn.predict(X_train_selected)
y_train_pred_knn[:10]
# Out:
# array([198166.66666666666, 183816.66666666666, 194633.33333333334,
#        122500.0, 139416.66666666666, 153800.0, 136962.33333333334,
#        246333.33333333334, 197633.33333333334, 229800.0], dtype=object)

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_knn=knn.predict(X_test_selected)
y_pred_knn[:10]
# Out:
# array([107850.0, 200933.33333333334, 172666.66666666666, 118300.0,
#        160666.66666666666, 85333.33333333333, 156166.66666666666,
#        124116.66666666667, 135633.33333333334, 150500.0], dtype=object)

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_knn=r2_score(y_pred_knn,y_test)
mae_knn=mean_absolute_error(y_pred_knn,y_test)
mse_knn=mean_squared_error(y_pred_knn,y_test)
relative_error_knn=mae_knn/(np.mean(y_test))*100
print("r2score knn:",r2_knn)
print("mean absolute error knn:",mae_knn)
print("mean squared error knn:",mse_knn)
print("relative error knn:",relative_error_knn)
# Out:
# r2score knn: 0.5699093000411554
# mean absolute error knn: 24318.546803652967
# mean squared error knn: 1584092580.9326484
# relative error knn: 13.643030531860422

# %%
from sklearn.svm import SVR
svr=SVR(C=1000, epsilon= 0.5, gamma='scale', kernel= 'linear')
svr.fit(X_train_selected,y_train)
# Out:
# SVR(C=1000, epsilon=0.5, kernel='linear')

# %%
y_pred_train_svr=svr.predict(X_train_selected)
y_pred_train_svr[:10]
# Out:
# array([203844.16039685, 164062.69183377, 201722.86957768, 123943.70737771,
#        137844.64238481, 117010.13518456, 125517.53759984, 272117.6351798 ,
#        274112.27001027, 263357.69026402])

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_svr=svr.predict(X_test_selected)
y_pred_svr[:10]
# Out:
# array([ 97108.44027165, 130981.67325143, 198911.40009717, 181857.66187695,
#        293606.28522614,  58790.10658959, 169582.99187402, 117090.97792939,
#        142500.81819371, 109636.42488412])

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_svr=r2_score(y_pred_svr,y_test)
mae_svr=mean_absolute_error(y_pred_svr,y_test)
mse_svr=mean_squared_error(y_pred_svr,y_test)
relative_error_svr=mae_svr/(np.mean(y_test))*100
print("r2score svr:",r2_svr)
print("mean absolute error svr:",mae_svr)
print("mean squared error svr:",mse_svr)
print("relative error svr:",relative_error_svr)
# Out:
# r2score svr: 0.6539300707979674
# mean absolute error svr: 18116.621461043713
# mean squared error svr: 1790671661.4844725
# relative error svr: 10.163667332706313

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
from scipy.stats import uniform,randint

# %%
#hyperparameter tuning
param_dist={
    'C':uniform(0.01,1000),
    'epsilon':uniform(0.001,1),
    'kernel':['rbf','linear'],
    'gamma':['scale','auto']
}
random_search=RandomizedSearchCV(SVR(),param_distributions=param_dist,scoring='r2',cv=5,n_jobs=-1,random_state=45)
random_search.fit(X_train_selected,y_train)
print("Best params:",random_search.best_params_)
print("Best score:",random_search.best_score_)
# Out:
# Best params: {'C': 989.0215134756002, 'epsilon': 0.5505447268447254, 'gamma': 'scale', 'kernel': 'linear'}
# Best score: 0.8551550899353348

# %%
param_grid={
    'C':[980,990,1000],
    'epsilon':[0.5,0.55,0.6],
    'kernel':['rbf','linear'],
    'gamma':['scale','auto']
}
grid_search=GridSearchCV(SVR(),param_grid=param_grid,scoring='r2',cv=5,n_jobs=-1)
grid_search.fit(X_train_selected,y_train)
print("Best params:",grid_search.best_params_)
print("Best score:",grid_search.best_score_)
# Out:
# Best params: {'C': 1000, 'epsilon': 0.5, 'gamma': 'scale', 'kernel': 'linear'}
# Best score: 0.8559072634290061

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(criterion= 'squared_error', max_depth= 10, max_features= 0.5, min_samples_leaf= 14, min_samples_split=14)
dtr.fit(X_train_selected,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, max_features=0.5, min_samples_leaf=14,
#                       min_samples_split=14)

# %%
y_train_pred_dtr=dtr.predict(X_train_selected)
y_train_pred_dtr[:10]
# Out:
# array([215406.7826087 , 189957.69230769, 215406.7826087 , 136819.375     ,
#        123957.        , 118935.71428571, 123239.13333333, 259708.78947368,
#        260224.5       , 259708.78947368])

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_dtr=dtr.predict(X_test_selected)
y_pred_dtr[:10]
# Out:
# array([ 97744.11764706, 124800.        , 193715.625     , 260224.5       ,
#        227427.71428571,  97744.11764706, 155356.66666667, 145075.        ,
#        132532.35294118, 108048.78571429])

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_dtr=r2_score(y_pred_dtr,y_test)
mae_dtr=mean_absolute_error(y_pred_dtr,y_test)
mse_dtr=mean_squared_error(y_pred_dtr,y_test)
relative_error_dtr=mae_dtr/(np.mean(y_test))*100
print("r2score dtr:",r2_dtr)
print("mean absolute error dtr:",mae_dtr)
print("mean squared error dtr:",mse_dtr)
print("relative error dtr:",relative_error_dtr)
# Out:
# r2score dtr: 0.7469442320601267
# mean absolute error dtr: 23726.805073383868
# mean squared error dtr: 1298692341.3015294
# relative error dtr: 13.311055494115795

# %%
#hyperparameter tuning
param_dist={
    'criterion':['squared_error','absolute_error'],
    'max_depth':randint(2,30),
    'min_samples_leaf':randint(2,20),
    'min_samples_split':randint(2,20),
    'max_features':[0.5,'log2','sqrt']
}
random_search=RandomizedSearchCV(DecisionTreeRegressor(),param_distributions=param_dist,scoring='r2',cv=5,n_jobs=-1,random_state=45)
random_search.fit(X_train_selected,y_train)
print("Best Params:",random_search.best_params_)
print("Best Scoring:",random_search.best_score_)
# Out:
# Best Params: {'criterion': 'absolute_error', 'max_depth': 8, 'max_features': 0.5, 'min_samples_leaf': 16, 'min_samples_split': 16}
# Best Scoring: 0.7487932215974198

# %%
param_grid={
    'criterion':['squared_error','absolute_error'],
    'max_depth':[6,8,10],
    'min_samples_leaf':[14,16,18],
    'min_samples_split':[14,16,18],
    'max_features':[0.5,'log2','sqrt']
}
grid_search=GridSearchCV(DecisionTreeRegressor(),param_grid=param_grid,scoring='r2',cv=5,n_jobs=-1)
grid_search.fit(X_train_selected,y_train)
print("Best Params:",grid_search.best_params_)
print("Best Scoring:",grid_search.best_score_)
# Out:
# Best Params: {'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 0.5, 'min_samples_leaf': 14, 'min_samples_split': 16}
# Best Scoring: 0.7675335805770696

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(max_depth=26, max_features= 0.5, min_samples_leaf=15, min_samples_split= 3, n_estimators=400)
rfr.fit(X_train_selected,y_train)
# Out:
# RandomForestRegressor(max_depth=26, max_features=0.5, min_samples_leaf=15,
#                       min_samples_split=3, n_estimators=400)

# %%
y_pred_train_rfr=rfr.predict(X_train_selected)
y_pred_train_rfr[:10]
# Out:
# array([193691.38104613, 182169.53198214, 192118.57207768, 137262.99826414,
#        134044.29375118, 121953.60884667, 133799.01567104, 262460.17107118,
#        246844.48052983, 293211.50328353])

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_rfr=rfr.predict(X_test_selected)
y_pred_rfr[:10]
# Out:
# array([113304.15559323, 127467.69013012, 198277.25293896, 154041.71266841,
#        292865.6953089 ,  89928.76183898, 151225.77614281, 142195.29608071,
#        134869.69286426, 125080.394122  ])

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_rfr=r2_score(y_pred_rfr,y_test)
mae_rfr=mean_absolute_error(y_pred_rfr,y_test)
mse_rfr=mean_squared_error(y_pred_rfr,y_test)
relative_error_rfr=mae_rfr/(np.mean(y_test))*100
print("r2score rfr:",r2_rfr)
print("mean absolute error rfr:",mae_rfr)
print("mean squared error rfr:",mse_rfr)
print("relative error rfr:",relative_error_rfr)
# Out:
# r2score rfr: 0.7938222357373704
# mean absolute error rfr: 17423.009015811
# mean squared error rfr: 854743584.3668063
# relative error rfr: 9.774541459191255

# %%
#hyperparameter tuning
param_dist={
    'n_estimators':randint(50,1000),
    'max_depth':randint(2,50),
    'min_samples_leaf':randint(2,50),
    'min_samples_split':randint(2,50),
    'max_features':[0.5,'sqrt','log2']
}
random_search=RandomizedSearchCV(RandomForestRegressor(),param_distributions=param_dist,scoring='r2',cv=5,n_jobs=-1,verbose=1,random_state=45)
random_search.fit(X_train_selected,y_train)
print("Best Params:",random_search.best_params_)
print("Best score:",random_search.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Params: {'max_depth': 23, 'max_features': 0.5, 'min_samples_leaf': 17, 'min_samples_split': 3, 'n_estimators': 448}
# Best score: 0.8264194225884592

# %%
param_grid={
    'n_estimators':[400,450,500],
    'max_depth':[20,23,26],
    'min_samples_leaf':[15,17,19],
    'min_samples_split':[2,3,4],
    'max_features':[0.5,'sqrt','log2']
}
grid_search=GridSearchCV(RandomForestRegressor(),param_grid=param_grid,scoring='r2',cv=5,n_jobs=-1,verbose=1)
grid_search.fit(X_train_selected,y_train)
print("Best Params:",grid_search.best_params_)
print("Best score:",grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# Best Params: {'max_depth': 26, 'max_features': 0.5, 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 400}
# Best score: 0.8332430766484424

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(X_train_selected,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred_train_gbr=gbr.predict(X_train_selected)
y_pred_train_gbr[:10]
# Out:
# array([192387.00384097, 178302.81361445, 186946.02793618, 133395.08254791,
#        138658.92547597, 130620.99092845, 121567.01878542, 251203.23262788,
#        245731.22819431, 305222.15520571])

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_gbr=gbr.predict(X_test_selected)
y_pred_gbr[:10]
# Out:
# array([109729.65747887, 136148.81965582, 190236.16704781, 177433.36418382,
#        312072.83500331,  63729.8571628 , 150779.33880602, 141544.53361962,
#        144593.68274381, 123226.49223502])

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_gbr=r2_score(y_pred_gbr,y_test)
mae_gbr=mean_absolute_error(y_pred_gbr,y_test)
mse_gbr=mean_squared_error(y_pred_gbr,y_test)
relative_error_gbr=mae_gbr/(np.mean(y_test))*100
print("r2score gbr:",r2_gbr)
print("mean absolute error gbr:",mae_gbr)
print("mean squared error gbr:",mse_gbr)
print("relative error gbr:",relative_error_gbr)
# Out:
# r2score gbr: 0.8763621582746675
# mean absolute error gbr: 14962.037539543699
# mean squared error gbr: 560827665.1584312
# relative error gbr: 8.393903493451091

# %%
#hyperparameter tuning 
param_dist={
    'n_estimators':randint(50,1000),
    'learning_rate':uniform(0.01,0.3),
    'max_depth':randint(3,20),
    'min_samples_split':randint(2,20),
    'min_samples_leaf':randint(1,20)
}
random_search=RandomizedSearchCV(GradientBoostingRegressor(),param_distributions=param_dist,n_iter=50,scoring="r2",cv=5,verbose=1,n_jobs=-1,random_state=45)
random_search.fit(X_train_selected,y_train)
print("Best parameters:",random_search.best_params_)
print("Best score:",random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'learning_rate': 0.04763024512222104, 'max_depth': 15, 'min_samples_leaf': 17, 'min_samples_split': 12, 'n_estimators': 106}
# Best score: 0.8599256564265028

# %%
param_grid={
    'n_estimators':[76,106,136],
    'learning_rate':[0.046,0.047,0.048],
    'max_depth':[13,15,17],
    'min_samples_split':[10,12,14],
    'min_samples_leaf':[15,17,19]
}
grid_search=GridSearchCV(GradientBoostingRegressor(),param_grid=param_grid,scoring="r2",cv=5,verbose=1,n_jobs=-1)
grid_search.fit(X_train_selected,y_train)
print("Best parameters:",grid_search.best_params_)
print("Best score:",grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# Best parameters: {'learning_rate': 0.048, 'max_depth': 13, 'min_samples_leaf': 19, 'min_samples_split': 14, 'n_estimators': 106}
# Best score: 0.8619953184113504

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
xgr=XGBRegressor(colsample_bytree= 0.7419289680981822, learning_rate= 0.04803575312116508, max_depth= 5, n_estimators= 475, reg_alpha= 0.20263586331845584, reg_lambda= 1.973463465677992, subsample= 0.8606475878305773)
xgr.fit(X_train_selected,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7419289680981822, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.04803575312116508,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=475, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
y_pred_train_xgr=xgr.predict(X_train_selected)
y_pred_train_xgr[:10]
# Out:
# array([195864.23 , 205217.84 , 188026.55 , 128650.26 , 133941.16 ,
#        121092.78 , 122965.555, 272701.4  , 249238.6  , 273739.34 ],
#       dtype=float32)

# %%
y_train[:10]
# Out:
# 727     194500
# 328     214500
# 958     185000
# 126     128000
# 1102    135000
# 312     119900
# 565     128000
# 600     275000
# 1386    250000
# 301     267000
# Name: SalePrice, dtype: object

# %%
y_pred_xgr=xgr.predict(X_test_selected)
y_pred_xgr[:10]
# Out:
# array([105648.7  , 140192.25 , 189362.81 , 165943.   , 321486.7  ,
#         72823.8  , 150845.27 , 134147.95 , 147058.   , 115990.266],
#       dtype=float32)

# %%
y_test[:10]
# Out:
# 140     115000
# 950     129000
# 248     180000
# 1360    189000
# 568     316600
# 1325     55000
# 1083    160000
# 784     128000
# 1183    120000
# 1407    112000
# Name: SalePrice, dtype: object

# %%
r2_xgr=r2_score(y_pred_xgr,y_test)
mae_xgr=mean_absolute_error(y_pred_xgr,y_test)
mse_xgr=mean_squared_error(y_pred_xgr,y_test)
relative_error_xgr=mae_xgr/(np.mean(y_test))*100
print("r2score xgr:",r2_xgr)
print("mean absolute error xgr:",mae_xgr)
print("mean squared error xgr:",mse_xgr)
print("relative error xgr:",relative_error_xgr)
# Out:
# r2score xgr: 0.8644845485687256
# mean absolute error xgr: 14850.855602525686
# mean squared error xgr: 630567987.2762679
# relative error xgr: 8.331528937373575

# %%
#hyperparameter tuning
param_dist={
    'n_estimators':randint(50,1000),
    'max_depth':randint(2,50),
    'learning_rate':uniform(0.01,0.2),
    'subsample':uniform(0.6,0.4),
    'colsample_bytree':uniform(0.6,0.4),
    'reg_alpha':uniform(0,1),
    'reg_lambda':uniform(1,1)
}
random_search=RandomizedSearchCV(XGBRegressor(),param_distributions=param_dist,n_iter=50,scoring="r2",cv=5,verbose=1,n_jobs=-1,random_state=45)
random_search.fit(X_train_selected,y_train)
print("Best parameters:",random_search.best_params_)
print("Best score:",random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'colsample_bytree': 0.7419289680981822, 'learning_rate': 0.04803575312116508, 'max_depth': 5, 'n_estimators': 475, 'reg_alpha': 0.20263586331845584, 'reg_lambda': 1.973463465677992, 'subsample': 0.8606475878305773}
# Best score: 0.8548609614372253
